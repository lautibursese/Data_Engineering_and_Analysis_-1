# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Predator/Desktop/Lauti/Programación/GitHub/2. Data Analytics/#2/datasets/olist_closed_deals_dataset.csv")
df
# Out:
#                                mql_id                         seller_id  \
# 0    5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1    a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2    327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3    f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4    ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
# ..                                ...                               ...
# 837  df9a2abe2ad3f2d8758b675ac8331ecf  bfcc27719640628da877db48b672b169
# 838  8723201570415eb23b4f095d8c20a27c  4a82eab98441aeb64566e2776c1fb2b6
# 839  2e57665b8faf05c967a801eb5aedfa0a  55031883943971ca22db6894574cfe2c
# 840  40955be51cc85c5a5a6cdd12b19e9f10  c0e933c238e41f0cd459d6025ee9b364
# 841  8a6492305a5fbcdcdd1a7f5a90764c07  1bba9c94eb5c4e82fba9f7286fe81025
#
#                                sdr_id                             sr_id  \
# ...

# %%
df.isna()
# Out:
#      mql_id  seller_id  sdr_id  sr_id  won_date  business_segment  lead_type  \
# 0     False      False   False  False     False             False      False
# 1     False      False   False  False     False             False      False
# 2     False      False   False  False     False             False      False
# 3     False      False   False  False     False             False      False
# 4     False      False   False  False     False             False      False
# ..      ...        ...     ...    ...       ...               ...        ...
# 837   False      False   False  False     False             False      False
# 838   False      False   False  False     False             False      False
# 839   False      False   False  False     False             False      False
# 840   False      False   False  False     False             False      False
# 841   False      False   False  False     False             False      False
#
# ...

# %%
data_nan = df.isna().sum().sum()
data_nan
# Out:
# 3300

# %%
rows, columns = df.shape
rows * columns
# Out:
# 11788

# %%
data_nan/ (rows*columns)
# Out:
# 0.27994570749915165

# %%
df.columns
# Out:
# Index(['mql_id', 'seller_id', 'sdr_id', 'sr_id', 'won_date',
#        'business_segment', 'lead_type', 'lead_behaviour_profile',
#        'has_company', 'has_gtin', 'average_stock', 'business_type',
#        'declared_product_catalog_size', 'declared_monthly_revenue'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
our_data = os.listdir("C:/Users/Predator/Desktop/Lauti/Programación/GitHub/2. Data Analytics/#2/datasets")
our_data
# Out:
# ['olist_closed_deals_dataset.csv',
#  'olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_marketing_qualified_leads_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'product_category_name_translation.csv']

# %%
data_dict = {}
for file in our_data:
    
    path = f"C:/Users/Predator/Desktop/Lauti/Programación/GitHub/2. Data Analytics/#2/datasets/{file}"
    df = pd.read_csv(path)
    data_nan = df.isna().sum().sum()
    rows, columns = df.shape
    percent_nan = data_nan/(rows*columns)
    name_columns = df.columns

    # Get known if at least one culumn is a date-format
    has_date = any(df.columns.str.contains("Date", case=False))

    duplicates = df.duplicated().sum()/rows

    data_dict[file] = {"percent_nan": percent_nan, 
                        "rows": rows, 
                        "columns": columns,
                        "has_date_column": has_date,
                        "percent_duplicates": duplicates}

data_dict
# Out:
# {'olist_closed_deals_dataset.csv': {'percent_nan': 0.27994570749915165,
#   'rows': 842,
#   'columns': 14,
#   'has_date_column': True,
#   'percent_duplicates': 0.0},
#  'olist_customers_dataset.csv': {'percent_nan': 0.0,
#   'rows': 99441,
#   'columns': 5,
#   'has_date_column': False,
#   'percent_duplicates': 0.0},
#  'olist_geolocation_dataset.csv': {'percent_nan': 0.0,
#   'rows': 1000163,
#   'columns': 5,
#   'has_date_column': False,
#   'percent_duplicates': 0.2617883285024541},
#  'olist_marketing_qualified_leads_dataset.csv': {'percent_nan': 0.001875,
#   'rows': 8000,
#   'columns': 4,
#   'has_date_column': True,
#   'percent_duplicates': 0.0},
#  'olist_orders_dataset.csv': {'percent_nan': 0.00616948743476031,
#   'rows': 99441,
#   'columns': 8,
#   'has_date_column': True,
#   'percent_duplicates': 0.0},
#  'olist_order_items_dataset.csv': {'percent_nan': 0.0,
#   'rows': 112650,
#   'columns': 7,
#   'has_date_column': True,
#   'percent_duplicates': 0.0},
# ...

# %%
data = pd.DataFrame(data_dict.values(), index=data_dict.keys())
data
# Out:
#                                              percent_nan     rows  columns  \
# olist_closed_deals_dataset.csv                  0.279946      842       14
# olist_customers_dataset.csv                     0.000000    99441        5
# olist_geolocation_dataset.csv                   0.000000  1000163        5
# olist_marketing_qualified_leads_dataset.csv     0.001875     8000        4
# olist_orders_dataset.csv                        0.006169    99441        8
# olist_order_items_dataset.csv                   0.000000   112650        7
# olist_order_payments_dataset.csv                0.000000   103886        5
# olist_order_reviews_dataset.csv                 0.210063    99224        7
# olist_products_dataset.csv                      0.008255    32951        9
# olist_sellers_dataset.csv                       0.000000     3095        4
# product_category_name_translation.csv           0.000000       71        2
#
#                                              has_date_column  \
# ...

# %%
total_data = (data.rows * data["columns"]).sum()
total_data
# Out:
# 8648965

# %%
total_nan = (data.percent_nan * data.rows * data["columns"]).sum()
total_nan
# Out:
# 156619.0

# %%
percent_total_nan = total_nan/total_data
percent_total_nan
# Out:
# 0.018108409503333638

# %%
percent_nan = data.sort_values("percent_nan", ascending=False)
ax = sns.barplot(data=percent_nan, x="percent_nan", y=percent_nan.index)
ax.set(xlabel="Percentage of nulls", ylabel="Datasets")
ax.set_title("Percentage of nulls per dataset")
# Out:
# Text(0.5, 1.0, 'Percentage of nulls per dataset')

# %%
labels = ["Nulls", "Not nulls"]
colors = ["tab:orange", "tab:blue" ]
plt.pie([percent_total_nan, 1-percent_total_nan], labels=labels, colors=colors, autopct='%.0f%%')
plt.title("Total percentage of nulls on datasets")
# Out:
# Text(0.5, 1.0, 'Total percentage of nulls on datasets')

# %%
sns.scatterplot(x=data['percent_nan'], y=data["rows"]*data["columns"])
# Out:
# <AxesSubplot:xlabel='percent_nan'>
