# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Predator/Desktop/Lauti/Programación/GitHub/2. Data Analytics/#2/datasets/olist_orders_dataset.csv", parse_dates=True)
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df[df["order_status"]=="canceled"]
# Out:
#                                order_id                       customer_id  \
# 397    1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 613    714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 1058   3a129877493c8189c59c60eb71d97c29  0913cdce793684e52bbfac69d87e91fd
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# ...                                 ...                               ...
# 98791  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99143  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
def replace_nulls(df, col_origen, col_destino):
    df[col_destino] = df[col_destino].fillna(df[col_origen].map(lambda x: x))
    return df

# %%
replace_nulls(df, "order_purchase_timestamp", "order_approved_at")
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
replace_nulls(df, "order_approved_at", "order_delivered_carrier_date")
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
replace_nulls(df, "order_delivered_carrier_date", "order_delivered_customer_date")
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
# We check if the changes applied correctly
df[df["order_status"]=="canceled"]
# Out:
#                                order_id                       customer_id  \
# 397    1b9ecfe83cdc259250e1a8aca174f0ad  6d6b50b66d79f80827b6d96751528d30
# 613    714fb133a6730ab81fa1d3c1b2007291  e3fe72696c4713d64d3c10afe71e75ed
# 1058   3a129877493c8189c59c60eb71d97c29  0913cdce793684e52bbfac69d87e91fd
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# ...                                 ...                               ...
# 98791  b159d0ce7cd881052da94fa165617b05  e0c3bc5ce0836b975d6b2a8ce7bb0e3e
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99143  6560fb10610771449cb0463c5ba12199  0d07d0a588caf93cc66b7a8aff86d2fe
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99441 non-null  object
#  5   order_delivered_carrier_date   99441 non-null  object
#  6   order_delivered_customer_date  99441 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# ### **Null values**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99441 non-null  object
#  5   order_delivered_carrier_date   99441 non-null  object
#  6   order_delivered_customer_date  99441 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
columns = df.columns.to_list()
for i in columns:
    print(f"Null values in {i}: =====> {df[i].isna().sum()} <===== in percentage: {round((df[i].isna().sum() / df.shape[0])*100, 2)}%")
# Out:
# Null values in order_id: =====> 0 <===== in percentage: 0.0%
# Null values in customer_id: =====> 0 <===== in percentage: 0.0%
# Null values in order_status: =====> 0 <===== in percentage: 0.0%
# Null values in order_purchase_timestamp: =====> 0 <===== in percentage: 0.0%
# Null values in order_approved_at: =====> 0 <===== in percentage: 0.0%
# Null values in order_delivered_carrier_date: =====> 0 <===== in percentage: 0.0%
# Null values in order_delivered_customer_date: =====> 0 <===== in percentage: 0.0%
# Null values in order_estimated_delivery_date: =====> 0 <===== in percentage: 0.0%

# %%
df["order_status"].value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %% [markdown]
# ### **`Date's column changes`**

# %%
purchase_timestamp = pd.to_datetime(df["order_purchase_timestamp"])

# %%
approved_at = pd.to_datetime(df["order_approved_at"])

# %%
delivered_carrier = pd.to_datetime(df["order_delivered_carrier_date"])

# %%
delivered_customer = pd.to_datetime(df["order_delivered_customer_date"])

# %%
estimated_delivery = pd.to_datetime(df["order_estimated_delivery_date"])

# %% [markdown]
# ### **`Dataframe with only dates, to find differences (later date - previous date)`**

# %%
dates = pd.concat([purchase_timestamp, approved_at, delivered_carrier, delivered_customer, estimated_delivery], axis=1)

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  1   order_approved_at              99441 non-null  datetime64[ns]
#  2   order_delivered_carrier_date   99441 non-null  datetime64[ns]
#  3   order_delivered_customer_date  99441 non-null  datetime64[ns]
#  4   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5)
# memory usage: 3.8 MB

# %%
dates["approved_and_purchased_difference"] = (dates["order_approved_at"]-dates["order_purchase_timestamp"])/pd.Timedelta(days=1)

# %%
dates[dates["approved_and_purchased_difference"]<0]["approved_and_purchased_difference"].count()
# Out:
# 0

# %%
dates["approved_and_carrier_difference"] = (dates["order_delivered_carrier_date"] - dates["order_approved_at"])/pd.Timedelta(days=1)

# %%
dates[dates["approved_and_carrier_difference"]<0]["approved_and_carrier_difference"].count()
# Out:
# 1359

# %%
# Max difference
dates[dates["approved_and_carrier_difference"]<0]["approved_and_carrier_difference"].min()
# Out:
# -171.21900462962964

# %%
dates[dates["approved_and_carrier_difference"]<0]["approved_and_carrier_difference"].idxmin()
# Out:
# 25883

# %%
dates.iloc[25883]
# Out:
# order_purchase_timestamp             2018-07-16 18:40:53
# order_approved_at                    2018-07-16 18:50:22
# order_delivered_carrier_date         2018-01-26 13:35:00
# order_delivered_customer_date        2018-07-23 20:04:45
# order_estimated_delivery_date        2018-08-07 00:00:00
# approved_and_purchased_difference               0.006586
# approved_and_carrier_difference              -171.219005
# Name: 25883, dtype: object

# %%
# Min difference
dates[dates["approved_and_carrier_difference"]<0]["approved_and_carrier_difference"].max()
# Out:
# -0.00024305555555555555

# %%
dates["client_and_carrier_difference"] = (dates["order_delivered_customer_date"] - dates["order_delivered_carrier_date"])/pd.Timedelta(days=1)

# %%
dates[dates["client_and_carrier_difference"]<0]["client_and_carrier_difference"].count()
# Out:
# 23

# %%
dates["client_and_estimated_delivery_difference"] = (dates["order_estimated_delivery_date"] - dates["order_delivered_customer_date"])/pd.Timedelta(days=1)

# %% [markdown]
# **Late deliveries:**

# %%
dates[dates["client_and_estimated_delivery_difference"]<0]["client_and_estimated_delivery_difference"].count()
# Out:
# 7841

# %% [markdown]
# **Deliveries on time:**

# %%
dates[dates["client_and_estimated_delivery_difference"]>0]["client_and_estimated_delivery_difference"].count()
# Out:
# 91600

# %% [markdown]
# ### **`Days difference between purchase date and the order delivered to the customer`**

# %%
dates["purchase_delivered_difference"] = (dates["order_delivered_customer_date"] - dates["order_purchase_timestamp"])/pd.Timedelta(days=1)

# %%
dates.head()
# Out:
#   order_purchase_timestamp   order_approved_at order_delivered_carrier_date  \
# 0      2017-10-02 10:56:33 2017-10-02 11:07:15          2017-10-04 19:55:00
# 1      2018-07-24 20:41:37 2018-07-26 03:24:27          2018-07-26 14:31:00
# 2      2018-08-08 08:38:49 2018-08-08 08:55:23          2018-08-08 13:50:00
# 3      2017-11-18 19:28:06 2017-11-18 19:45:59          2017-11-22 13:39:59
# 4      2018-02-13 21:18:39 2018-02-13 22:20:29          2018-02-14 19:46:34
#
#   order_delivered_customer_date order_estimated_delivery_date  \
# 0           2017-10-10 21:25:13                    2017-10-18
# 1           2018-08-07 15:27:45                    2018-08-13
# 2           2018-08-17 18:06:29                    2018-09-04
# 3           2017-12-02 00:28:42                    2017-12-15
# 4           2018-02-16 18:17:02                    2018-02-26
#
#    approved_and_purchased_difference  approved_and_carrier_difference  \
# ...

# %%
dates[dates["purchase_delivered_difference"]<0]
# Out:
#      order_purchase_timestamp   order_approved_at  \
# 4159      2018-04-30 14:06:12 2018-04-30 14:15:24
#
#      order_delivered_carrier_date order_delivered_customer_date  \
# 4159          2018-04-30 12:59:00           2018-04-30 12:59:00
#
#      order_estimated_delivery_date  approved_and_purchased_difference  \
# 4159                    2018-05-28                           0.006389
#
#       approved_and_carrier_difference  client_and_carrier_difference  \
# 4159                        -0.053056                            0.0
#
#       client_and_estimated_delivery_difference  purchase_delivered_difference
# 4159                                 27.459028                      -0.046667

# %%
dates["purchase_delivered_difference"].max()
# Out:
# 209.6286111111111

# %%
dates["purchase_delivered_difference"].min()
# Out:
# -0.04666666666666667

# %% [markdown]
# ### **`Average days delivering the product:`**

# %%
dates["purchase_delivered_difference"].mean()
# Out:
# 12.241221372495398

# %% [markdown]
# ### **Duplicated values**

# %%
df[df.duplicated(subset="order_id")]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []
